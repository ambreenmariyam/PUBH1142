# %% [markdown]
# # TITLE

# %%
# Add 100 and 104 
result = 100 + 104
print(result)  # Output: 204
# Out:
# 204

# %% [markdown]
# Epidemeology is an interdisciplinary field that studies the distribution and determinants of health-related states or events in specified populations, and applies this study to control health problems. It is a cornerstone of public health and helps inform policy decisions and evidence-based practices by identifying risk factors for disease and targets for preventive healthcare.
